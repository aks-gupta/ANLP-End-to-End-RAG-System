# %%
import os
from typing import List, Dict, Any
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_huggingface import HuggingFaceEmbeddings
from langchain.vectorstores import FAISS
from rank_bm25 import BM25Okapi
from transformers import AutoModelForSequenceClassification, AutoTokenizer
import torch
from langchain.retrievers import BM25Retriever, EnsembleRetriever
from langchain_ollama import OllamaLLM
from langchain.chains import RetrievalQA
from langchain.schema import Document, BaseRetriever

# %%
def load_and_split_data(directory_path: str) -> List[str]:
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=1000,  # Smaller chunks
        chunk_overlap=100,
        length_function=len,
        separators=["\n\n", "\n", " ", ""]
    )
    docs = []
    for file in os.listdir(directory_path):
        if file.endswith(".txt"):
            with open(os.path.join(directory_path, file), 'r') as f:
                text = f.read()
                docs.extend(text_splitter.split_text(text))
    return docs

# %%
context_docs = load_and_split_data('./data')
print(len(context_docs))
# Out:
# 4254

# %%
embeddings = HuggingFaceEmbeddings(model_name='sentence-transformers/all-mpnet-base-v2')
vector_store = FAISS.from_texts(context_docs, embeddings)

# %%
reranker_model = AutoModelForSequenceClassification.from_pretrained("cross-encoder/ms-marco-MiniLM-L-12-v2")
reranker_tokenizer = AutoTokenizer.from_pretrained("cross-encoder/ms-marco-MiniLM-L-12-v2")

def rerank_documents(query: str, docs: List[str], top_k: int = 5) -> List[str]:
    pairs = [[query, doc] for doc in docs]
    inputs = reranker_tokenizer(pairs, padding=True, truncation=True, return_tensors="pt", max_length=512)
    
    with torch.no_grad():
        scores = reranker_model(**inputs).logits.squeeze()
    
    ranked_results = sorted(zip(docs, scores), key=lambda x: x[1], reverse=True)
    return [doc for doc, score in ranked_results[:top_k]]

# %%
from transformers import T5Tokenizer, T5ForConditionalGeneration

query_expansion_tokenizer = T5Tokenizer.from_pretrained("BeIR/query-gen-msmarco-t5-base-v1")
query_expansion_model = T5ForConditionalGeneration.from_pretrained("BeIR/query-gen-msmarco-t5-base-v1")

def expand_query(query: str, num_expansions: int = 3) -> List[str]:
    input_ids = query_expansion_tokenizer.encode(f"Expand the query: {query}", return_tensors="pt", max_length=64, truncation=True)
    outputs = query_expansion_model.generate(
        input_ids=input_ids,
        max_length=64,
        num_return_sequences=num_expansions,
        num_beams=num_expansions,
        no_repeat_ngram_size=2
    )
    expanded_queries = [query_expansion_tokenizer.decode(output, skip_special_tokens=True) for output in outputs]
    return [query] + expanded_queries
# Out:
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565

# %%
bm25_retriever = BM25Retriever.from_texts(context_docs)
bm25_retriever.k = 5  # Set the number of documents to retrieve

faiss_retriever = vector_store.as_retriever(search_kwargs={"k": 5})

ensemble_retriever = EnsembleRetriever(
    retrievers=[bm25_retriever, faiss_retriever],
    weights=[0.5, 0.5]
)

# %%
def improved_retrieval(query: str, top_k: int = 5) -> List[str]:
    # Query expansion
    expanded_queries = expand_query(query)
    
    all_docs = []
    for q in expanded_queries:
        # Hybrid retrieval
        docs = ensemble_retriever.get_relevant_documents(q)
        all_docs.extend([doc.page_content for doc in docs])
    
    # Remove duplicates
    unique_docs = list(set(all_docs))
    
    # Re-ranking
    reranked_docs = rerank_documents(query, unique_docs, top_k)
    
    return reranked_docs

# %%
llama_llm = OllamaLLM(model="llama3.2")

# %%
class ImprovedRetriever(BaseRetriever):
    def get_relevant_documents(self, query: str) -> List[Document]:
        docs = improved_retrieval(query)
        return [Document(page_content=doc) for doc in docs]

    async def aget_relevant_documents(self, query: str) -> List[Document]:
        return self.get_relevant_documents(query)

improved_retriever = ImprovedRetriever()
# Out:
# /var/folders/hd/8_t1xxs95sd1llh_9vxkkj9w0000gn/T/ipykernel_65432/662686558.py:1: DeprecationWarning: Retrievers must implement abstract `_get_relevant_documents` method instead of `get_relevant_documents`
#   class ImprovedRetriever(BaseRetriever):
# /var/folders/hd/8_t1xxs95sd1llh_9vxkkj9w0000gn/T/ipykernel_65432/662686558.py:1: DeprecationWarning: Retrievers must implement abstract `_aget_relevant_documents` method instead of `aget_relevant_documents`
#   class ImprovedRetriever(BaseRetriever):

# %%
from langchain.prompts import FewShotPromptTemplate, PromptTemplate

few_shot_examples = [
    {"question": "What is the name of the annual pickle festival held in Pittsburgh?", "answer": "Picklesburgh"},
    {"question": "When was the Pittsburgh Soul Food Festival established?", "answer": "2019"},
    {"question": "Who is performing the Opera event on 7th November?", "answer": "Cavalleria Rusticana and Pagliacci"},
    {"question": "When is the Syracuse Orange vs. Robert Morris Colonials women’s ice hockey game scheduled?", "answer": "February 8, 2025"},
    {"question": "How many Super Bowls have the Pittsburgh Steelers won?", "answer": "Six"},
    {"question": "Where is the \"Like, Totally Transformative: CMU in the 1980s\" exhibit being held?", "answer": "Hunt Library Gallery"},
#     {"question": "What is the most famous viewpoint in Pittsburgh?", "answer": "Mount Washington"},
#     {"question": "Which musician known for \"Black and Yellow\" hails from Pittsburgh?", "answer": "Wiz Khalifa"},
#     {"question": "What nickname is often used for Pittsburgh?", "answer": "The Steel City"},
#     {"question": "What is the name of the annual music festival in Pittsburgh?", "answer": "Pittsburgh Taco Festival"}
]

example_prompt = PromptTemplate(
    input_variables=["question", "answer"],
    template="Question: {question}\nAnswer: {answer}"
)

few_shot_prompt = FewShotPromptTemplate(
    examples=few_shot_examples,
    example_prompt=example_prompt,
    prefix="Answer the following question based on the context provided. Keep the answer as short as possible. Do not include any other information. Here are some examples:",
    suffix="Context: {context}\nQuestion: {question}\nAnswer:",
    input_variables=["context", "question"],
    example_separator="\n\n"
)

# %%
qa_chain = RetrievalQA.from_chain_type(
    llm=llama_llm,
    chain_type="stuff",
    retriever=improved_retriever,
    chain_type_kwargs={"prompt": few_shot_prompt}
)

# %%
def get_answer(question):
    result = qa_chain.invoke({"query": question})
    return result["result"]

# %%
query = "Which event is happening at Benedum Center on January 7, 2025?"
result = get_answer(query)
print(result)
# Out:
# No events listed

# %%
def get_top_k_relevant_documents(query, k=3):
    docs = improved_retriever.get_relevant_documents(query)
    return docs[:k]

top_k_docs = get_top_k_relevant_documents(query, k=5)

print(f"Top {len(top_k_docs)} relevant documents for the query: '{query}'")
for i, doc in enumerate(top_k_docs, 1):
    print(f"\nDocument {i}:")
    print(doc.page_content[:200] + "...")  # Print first 200 characters of each document

# %%
# Load questions and answers from separate files
with open("./test/questions.txt", "r") as f:
    questions = [line.strip() for line in f]

with open("./test/reference_answers.txt", "r") as f:
    answers = [line.strip() for line in f]

# Combine questions and answers
test_qa_data = [{"question": q, "answer": a} for q, a in zip(questions, answers)]

# %%
from nltk.translate.bleu_score import sentence_bleu
from nltk.tokenize import word_tokenize
from sklearn.metrics import f1_score
import numpy as np
import string

def calculate_metrics(predicted, actual):
    predicted = predicted.strip().lower()
    actual_answers = [ans.strip().lower() for ans in actual.split(';')]
    
    predicted = predicted.translate(str.maketrans('', '', string.punctuation))
    actual_answers = [ans.translate(str.maketrans('', '', string.punctuation)) for ans in actual_answers]
    
    predicted_tokens = word_tokenize(predicted)
    actual_tokens = [word_tokenize(ans) for ans in actual_answers]
    
    exact_match = any(predicted == ans for ans in actual_answers)
    
    f1_scores = []
    for ans in actual_tokens:
        true_positives = len(set(predicted_tokens) & set(ans))
        precision = true_positives / len(predicted_tokens) if predicted_tokens else 0
        recall = true_positives / len(ans) if ans else 0
        f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
        f1_scores.append(f1)
    
    max_f1 = max(f1_scores)
    
    answer_recall = any(all(word in predicted_tokens for word in ans) for ans in actual_tokens)
    
    return exact_match, max_f1, answer_recall

# %%
results = []
for qa in test_qa_data:
    question = qa['question']
    actual_answer = qa['answer']
    predicted_answer = qa_chain.invoke({"query": question})['result']
    
    exact_match, f1, answer_recall = calculate_metrics(predicted_answer, actual_answer)
    
    results.append({
        'question': question,
        'predicted_answer': predicted_answer,
        'actual_answer': actual_answer,
        'exact_match': exact_match,
        'f1_score': f1,
        'answer_recall': answer_recall
    })

average_exact_match = np.mean([r['exact_match'] for r in results])
average_f1 = np.mean([r['f1_score'] for r in results])
average_answer_recall = np.mean([r['answer_recall'] for r in results])

print(f"Average Exact Match: {average_exact_match:.4f}")
print(f"Average F1 Score: {average_f1:.4f}")
print(f"Average Answer Recall: {average_answer_recall:.4f}")

for r in results:
    print(f"\nQuestion: {r['question']}")
    print(f"Predicted Answer: {r['predicted_answer']}")
    print(f"Actual Answer: {r['actual_answer']}")
    print(f"Exact Match: {r['exact_match']}")
    print(f"F1 Score: {r['f1_score']:.4f}")
    print(f"Answer Recall: {r['answer_recall']}")
# Out:
# Average Exact Match: 0.3190
# Average F1 Score: 0.5180
# Average Answer Recall: 0.5259
#
# Question: What is the name of the Carnegie Mellon University mascot?
# Predicted Answer: Scotty
# Actual Answer: Scotty;Scotty the Scottish Terrier
# Exact Match: True
# F1 Score: 1.0000
# Answer Recall: True
#
# Question: What conference do the Carnegie Mellon Tartans football team compete in?
# Predicted Answer: Presidents' Athletic Conference
# Actual Answer: Presidents' Athletic Conference (PAC); Presidents' Athletic Conference (PAC), NCAA Division III; Presidents' Athletic Conference
# Exact Match: True
# F1 Score: 1.0000
# Answer Recall: True
#
# Question: What are the main professional sports teams in Pittsburgh?
# Predicted Answer: Pittsburgh Pirates (MLB), Pittsburgh Steelers (NFL), and Pittsburgh Penguins (NHL)
# Actual Answer: Pittsburgh Steelers (NFL), Pittsburgh Penguins (NHL), Pittsburgh Pirates (MLB); Pittsburgh Steelers, Pittsburgh Penguins and Pittsburgh Pirates; Steelers, Penguins, Pirates
# Exact Match: False
# F1 Score: 0.7368
# Answer Recall: True
#
# Question: Where do the Pittsburgh Steelers play their home games?
# Predicted Answer: Acrisure Stadium, North Shore neighborhood of Pittsburgh, Pennsylvania.
# Actual Answer: Acrisure Stadium
# Exact Match: False
# F1 Score: 0.4000
# Answer Recall: True
#
# Question: When was the last time the Pittsburgh Penguins won the Stanley Cup?
# Predicted Answer: 2017
# Actual Answer: 2017; 2016 and 2017
# Exact Match: True
# F1 Score: 1.0000
# Answer Recall: True
#
# Question: How many World Series have Pittsburgh Pirates won?
# Predicted Answer: Five.
# Actual Answer: 5; five
# Exact Match: True
# F1 Score: 1.0000
# Answer Recall: True
#
# Question: What is the history of the Pittsburgh Pirates' World Series wins?
# Predicted Answer: The team won five World Series titles (1909, 1925, 1960, 1971, 1979), and also won pre-World Series titles in 1901 and 1902.
# Actual Answer: 1909, 1925, 1960, 1971, 1979
# Exact Match: False
# F1 Score: 0.3704
# Answer Recall: True
#
# Question: What is the "Like, Totally Transformative: CMU in the 1980s" exhibit about?
# Predicted Answer: This University Libraries' exhibit is a portal to the past, a snapshot of life on campus more than four decades ago as our world began to transform!
# Actual Answer: Showcase into the campus life transformation during 1980s.
# Exact Match: False
# F1 Score: 0.1714
# Answer Recall: False
#
# Question: What teams are playing in the women’s ice hockey game on February 8, 2025?
# Predicted Answer: Syracuse Orange vs. Robert Morris Colonials
# Actual Answer: Syracuse Orange, Robert Morris Colonials
# Exact Match: False
# F1 Score: 0.9091
# Answer Recall: True
#
# Question: Where will the Syracuse Orange at Robert Morris Colonials women’s ice hockey game take place?
# Predicted Answer: Clearview Arena (Formerly RMU Island Sports Center) 15225, Pittsburgh, Pennsylvania, US.
# Actual Answer: Clearview Arena
# Exact Match: False
# F1 Score: 0.3077
# Answer Recall: True
#
# Question: What is the Pittsburgh baseball team called?
# Predicted Answer: Pirates
# Actual Answer: Pirates; Pittsburgh Pirates
# Exact Match: True
# F1 Score: 1.0000
# Answer Recall: True
#
# Question: When is the next Pittsburgh Steelers match?
# Predicted Answer: Week 3 of the 2024 season on Saturday, August 24.
# Actual Answer: Sun 11/10 at 1:00 PM EST; Sunday, November 10th at 1:00 PM EST; Novemeber 10, 2024
# Exact Match: False
# F1 Score: 0.1538
# Answer Recall: False
#
# Question: Who is the next Pittsburgh Steelers match against?
# Predicted Answer: Cincinnati Bengals
# Actual Answer: Washington Commanders
# Exact Match: False
# F1 Score: 0.0000
# Answer Recall: False
#
# Question: Why are Pittsburgh colours Black and Gold?
# Predicted Answer: Because of William Pitt's coat of arms.
# Actual Answer: William Pitt's coat of arms; After the founder of Pittsburgh, William Pitt's coat of arms
# Exact Match: False
# F1 Score: 0.8333
# Answer Recall: True
#
# Question: Is there an Art Exhibition anytime soon?
# Predicted Answer: Yes, several art exhibitions are happening soon.
#
# 1. "65 Artists, 65 Years: An Anniversary Exhibition" (Oct 18, 2024 to Nov 8, 2024)
# 2. Shaping the Future: National Showcase of Emerging Sculptors (Oct 18, 2024 to Nov 8, 2024)
# Actual Answer: Yes, The International Exhibition of Botanical Art & Illustration
# Exact Match: False
# F1 Score: 0.2174
# Answer Recall: False
#
# Question: Are there any Trivia Night events happening anytime soon?
# Predicted Answer: No specific trivia night event is mentioned, but Jurassic Park trivia night is listed as an upcoming event.
# Actual Answer: Lawrenceville Distilling Co, 5410 Harrison Street, every Thursday from 7 p.m.
# Exact Match: False
# F1 Score: 0.0000
# Answer Recall: False
#
# Question: When do Pittsburgh Steelers play the Kansas City Chiefs?
# Predicted Answer: Wed 12/25
# Actual Answer: December 25th, 2025; 12/25/2025
# Exact Match: False
# F1 Score: 0.0000
# Answer Recall: False
#
# Question: Who do the Pittsburgh Pirates play on February 23, 2025?
# Predicted Answer: There is no information provided to determine who the Pittsburgh Pirates will be playing on February 23, 2025.
# Actual Answer: Minnesota Twins
# Exact Match: False
# F1 Score: 0.0000
# Answer Recall: False
#
# Question: What is the next home game for the Pittsburgh Pirates?
# Predicted Answer: Not specified.
# Actual Answer: February 23, 2025; 02/23/2025
# Exact Match: False
# F1 Score: 0.0000
# Answer Recall: False
#
# Question: How many games will the Pirates play at LECOM Park in Bradenton in March 2025?
# Predicted Answer: 10
# Actual Answer: 8; eight
# Exact Match: False
# F1 Score: 0.0000
# Answer Recall: False
#
# Question: When and where is the Pirates game against the Braves?
# Predicted Answer: 09/26-28, 25, Truist Park - Atlanta
# Actual Answer: February 25, 2025, LECOM Park in Bradenton; March 8, 2025, CoolToday Park in North Port; February 25th, 2025 at LECOM Park and March 8th, 2025 at CoolToday Park.
# Exact Match: False
# F1 Score: 0.3333
# Answer Recall: False
#
# Question: Are there any Pittsburgh Penguins games happening in April?
# Predicted Answer: Yes, multiple matches are listed for the month of April.
# Actual Answer: Yes; 7; seven games
# Exact Match: False
# F1 Score: 0.1818
# Answer Recall: True
#
# Question: How many home games are the Pittsburgh Penguins playing in April?
# Predicted Answer: Seven.
# Actual Answer: 3; three
# Exact Match: False
# F1 Score: 0.0000
# Answer Recall: False
#
# Question: Where will the Penguins' game against Boston on April 13 be held?
# Predicted Answer: PPG Paints Arena Pittsburgh
# Actual Answer: PPG Paints Arena
# Exact Match: False
# F1 Score: 0.8571
# Answer Recall: True
#
# Question: When is Alan Walker coming to Pittsburgh?
# Predicted Answer: Feb 13, 2025
# Actual Answer: February 13, 2025; 02/13/2025
# Exact Match: False
# F1 Score: 0.6667
# Answer Recall: False
#
# Question: What is the link to get tickets for Pittsburgh Symphony Orchestra?
# Predicted Answer: https://pittsburgh.events/tickets/pittsburgh-symphony-orchestra/
# Actual Answer: https://pittsburgh.events/tickets/pittsburgh-symphony-orchestra/
# Exact Match: True
# F1 Score: 1.0000
# Answer Recall: True
#
# Question: When is the Arizona Diamondbacks game scheduled to take place?
# Predicted Answer: Thursday, July 25 and Friday, July 26, 2025
# Actual Answer: July 25 2025; 07/25/2025
# Exact Match: False
# F1 Score: 0.5455
# Answer Recall: True
#
# Question: What is the & Juliet event about?
# Predicted Answer: A new musical that flips the script on Romeo and Juliet, created by the Emmy-winning writer from “Schitt’s Creek.”
# Actual Answer: A comedy musical flipping the classic love story of Romeo and Juliet.
# Exact Match: False
# F1 Score: 0.3429
# Answer Recall: False
#
# Question: What is the date of the Steelers game against Kansas City Chiefs?
# Predicted Answer: December 25, -0001
# Actual Answer: December 25th, 2025
# Exact Match: False
# F1 Score: 0.3333
# Answer Recall: False
#
# Question: When is the Three Rivers Arts Festival held?
# Predicted Answer: June
# Actual Answer: June; June every year; Three Rivers Arts Festival is held every year in June
# Exact Match: True
# F1 Score: 1.0000
# Answer Recall: True
#
# Question: When was the Three Rivers Arts Festival founded?
# Predicted Answer: 1960
# Actual Answer: 1960; Founded in 1960
# Exact Match: True
# F1 Score: 1.0000
# Answer Recall: True
#
# Question: What is Light Up Night?
# Predicted Answer: Light Up Night is a family festival in Pittsburgh, Pennsylvania that marks the unofficial start of the Winter holiday shopping season.
# Actual Answer: Light Up Night is a family festival in the city of Pittsburgh
# Exact Match: False
# F1 Score: 0.6667
# Answer Recall: False
#
# Question: When was the Carnegie Museum of Art established?
# Predicted Answer: 1895
# Actual Answer: 1895; The Carnegie Museum of Art was founded in 1895
# Exact Match: True
# F1 Score: 1.0000
# Answer Recall: True
#
# Question: What is the mission of the Carnegie Museum of Art?
# Predicted Answer: Create experiences that connect people to art, ideas, and one another.
# Actual Answer: To create experiences that connect people to art, ideas, and one another; connect people to art, ideas, and one another
# Exact Match: False
# F1 Score: 0.9565
# Answer Recall: True
#
# Question: What is the name of the movie theatre in Carnegie Science Center?
# Predicted Answer: Penn Theater
# Actual Answer: Rango's Giant Cinema; Rango's Giant Theatre; Rango Giant Theatre; Rango Giant Cinema
# Exact Match: False
# F1 Score: 0.0000
# Answer Recall: False
#
# Question: What are the operating hours of the Carnegie Museum of Natural History?
# Predicted Answer: Sunday 10:00 am – 5:00 pm
# Monday 10:00 am – 5:00 pm
# Tuesday Closed
# Wednesday 10:00 am – 5:00 pm
# Thursday 10:00 am – 8:00 pm
# Friday 10:00 am – 5:00 pm
# Saturday 10:00 am – 5:00 pm
# Actual Answer: 10:00 am – 5:00 pm (Closed on Tuesdays); Mon., Wed., Fri.-Sun. 10 a.m.–5 p.m., Thurs.: 10 a.m.–8 p.m., Closed Tuesdays
# Exact Match: False
# F1 Score: 0.2609
# Answer Recall: False
#
# Question: What event takes place at Carnegie Museum of Natural History on October 26th?
# Predicted Answer: There is no information about an event taking place on October 26th.
# Actual Answer: Super Science Saturday: Booseum Trick or Treat
# Exact Match: False
# F1 Score: 0.0000
# Answer Recall: False
#
# Question: When did the Andy Warhoal Museum open?
# Predicted Answer: May 13, 1994.
# Actual Answer: May 13, 1994
# Exact Match: True
# F1 Score: 1.0000
# Answer Recall: True
#
# Question: When is the 2024 Teacher Open House at the Andy Warhoal Museum?
# Predicted Answer: Thursday, November 7, 2024, 4:30pm–8:30pm
# Actual Answer: Thursday, November 7, 2024, from 4:30 pm to 8:30 pm
# Exact Match: False
# F1 Score: 0.5333
# Answer Recall: False
#
# Question: What kind of collections does the Andy Warhoal museum have?
# Predicted Answer: The Andy Warhol Museum has a collection of paintings, drawings, commercial illustrations, sculptures, prints, photographs, wallpapers, sketchbooks, and books covering the entire range of Warhol's career.
# Actual Answer: Warhol’s artworks and archival materials; collection of Warhoal's arts and archives
# Exact Match: False
# F1 Score: 0.1875
# Answer Recall: False
#
# Question: What is the focus of the City of Champions exhibit in the Western Pennsylvania Sports Museum?
# Predicted Answer: The city's sports legends and championship teams across various disciplines.
# Actual Answer: Pittsburgh’s success in football, baseball, hockey, and individual sports
# Exact Match: False
# F1 Score: 0.1905
# Answer Recall: False
#
# Question: What is the name of the famous ketchup brand established in Pittsburgh?
# Predicted Answer: Heinz
# Actual Answer: Heinz; Heinz Ketchup
# Exact Match: True
# F1 Score: 1.0000
# Answer Recall: True
#
# Question: Which buses go to the Frick Museum?
# Predicted Answer: The 50th Street & Penn Avenue bus and the 19th Street & Penn Avenue bus.
# Actual Answer: Pittsburgh Regional Transit buses 67 and 69; 67 and 69
# Exact Match: False
# F1 Score: 0.1250
# Answer Recall: False
#
# Question: What is Pittsburgh Restaurant Week?
# Predicted Answer: Pittsburgh Restaurant Week is an annual city-wide event that features over 50 restaurants offering special dining deals.
# Actual Answer: A food festival that features Pittsburgh's finest restaurants
# Exact Match: False
# F1 Score: 0.2400
# Answer Recall: False
#
# Question: Who founded the Pittsburgh Taco Festival?
# Predicted Answer: Craig McCloud
# Actual Answer: Craig McCloud
# Exact Match: True
# F1 Score: 1.0000
# Answer Recall: True
#
# Question: How long is Little Italy Days for?
# Predicted Answer: Four days.
# Actual Answer: Four days
# Exact Match: True
# F1 Score: 1.0000
# Answer Recall: True
#
# Question: Where was the Banana Split invented?
# Predicted Answer: Latrobe, Pennsylvania.
# Actual Answer: Latrobe, Pennsylvania
# Exact Match: True
# F1 Score: 1.0000
# Answer Recall: True
#
# Question: What is the new name for the Carnegie Science Center?
# Predicted Answer: The Daniel G. and Carole L. Kamin Science Center
# Actual Answer: The Daniel G. and Carole L. Kamin Science Center
# Exact Match: True
# F1 Score: 1.0000
# Answer Recall: True
#
# Question: What is the PHMC?
# Predicted Answer: The Pennsylvania Historical and Museum Commission (PHMC).
# Actual Answer: The Pennsylvania Historical and Museum Commission ( PHMC ) ; Pennsylvania Historical and Museum Commission
# Exact Match: False
# F1 Score: 1.0000
# Answer Recall: True
#
# Question: What is Randyland?
# Predicted Answer: Randyland is an art museum in the North Side section of Pittsburgh, Pennsylvania, showcasing found object art and widely regarded as one of America's most colorful public art landmarks.
# Actual Answer: A colorful public art museum in the North Side section of Pittsburgh
# Exact Match: False
# F1 Score: 0.5366
# Answer Recall: False
#
# Question: How long can an opera be?
# Predicted Answer: 2 hours, 36 minutes
# Actual Answer: Operas come in all shapes and sizes, with some being as short as 13 minutes or as long as 7 days; 13 minutes to 7 days
# Exact Match: False
# F1 Score: 0.2222
# Answer Recall: False
#
# Question: Who is the current leader of Pittsburgh Opera?
# Predicted Answer: Christopher Hahn.
# Actual Answer: Christopher Hahn; The current leader of Pittsburgh Opera is Christopher Hahn
# Exact Match: True
# F1 Score: 1.0000
# Answer Recall: True
#
# Question: When was Pittsburgh Opera founded?
# Predicted Answer: 1939
# Actual Answer: 1939
# Exact Match: True
# F1 Score: 1.0000
# Answer Recall: True
#
# Question: When is the event featuring TOSCA taking place?
# Predicted Answer: When: October 5, 8, 11, 13, 2024
#
# (Also listed in performance dates)
# Actual Answer: October 5, 8, 11, 13, 2024; Oct 5th, 8th, 11th and 13th
# Exact Match: False
# F1 Score: 0.6667
# Answer Recall: True
#
# Question: Where does MJ The Musical take place?
# Predicted Answer: Benedum Center
# Actual Answer: Benedum Center
# Exact Match: True
# F1 Score: 1.0000
# Answer Recall: True
#
# Question: What is the Pittsburgh Cultural Trust?
# Predicted Answer: A non-profit arts organization.
# Actual Answer: An organization that oversees the cultural transformation of Pittsburgh's arts and entertainment district
# Exact Match: False
# F1 Score: 0.2353
# Answer Recall: False
#
# Question: What type of event is Britsburgh?
# Predicted Answer: Festival
# Actual Answer: A festival celebrating British culture in Pittsburgh
# Exact Match: False
# F1 Score: 0.2500
# Answer Recall: False
#
# Question: Which performing arts groups are part of the Pittsburgh Cultural District?
# Predicted Answer: Pittsburgh Ballet Theatre, Pittsburgh CLO, Pittsburgh Opera, Pittsburgh Public Theater, Pittsburgh Symphony, and August Wilson Center for African American Culture.
# Actual Answer: The Pittsburgh Ballet Theatre, the Pittsburgh CLO, the Pittsburgh Opera, and the Pittsburgh Symphony
# Exact Match: False
# F1 Score: 0.4118
# Answer Recall: False
#
# Question: Where do the performances of the Pittsburgh Symphony Orchestra take place?
# Predicted Answer: Heinz Hall
# Actual Answer: Heinz Hall
# Exact Match: True
# F1 Score: 1.0000
# Answer Recall: True
#
# Question: What is the title of the orchestra taking place on Novemeber 8th?
# Predicted Answer: Chicago: The Musical in Concert
# Actual Answer: Chicago: The Musical in Concert
# Exact Match: True
# F1 Score: 1.0000
# Answer Recall: True
#
# Question: Who is the current music director of the Pittsburgh Symphony Orchestra?
# Predicted Answer: Manfred Honeck
# Actual Answer: Manfred Honeck
# Exact Match: True
# F1 Score: 1.0000
# Answer Recall: True
#
# Question: How often does the Pittsburgh Restaurant Week take place?
# Predicted Answer: Twice a year, in Summer and Winter.
# Actual Answer: Twice a year, in Summer and Winter
# Exact Match: True
# F1 Score: 1.0000
# Answer Recall: True
#
# Question: What is the approximate runtime of the opera Tosca?
# Predicted Answer: 2 hours, 36 minutes
# Actual Answer: 2 hours 36 minutes
# Exact Match: True
# F1 Score: 1.0000
# Answer Recall: True
#
# Question: How many days a week is the Carnegie Science Center open?
# Predicted Answer: Five (Mon., Wed., Fri.-Sun.)
# Actual Answer: 6 days (closed on Tuesdays); 6
# Exact Match: False
# F1 Score: 0.0000
# Answer Recall: False
#
# Question: What event is taking place at the Harris Theater on November 7th?
# Predicted Answer: Unfortunately, the answer isn't provided in the given context.
# Actual Answer: Film Heroineburgh Customfest
# Exact Match: False
# F1 Score: 0.0000
# Answer Recall: False
#
# Question: Where does Little Italy Days take place?
# Predicted Answer: Bloomfield from Ella St. to Gross St.
# Actual Answer: Bloomfield
# Exact Match: False
# F1 Score: 0.2500
# Answer Recall: True
#
# Question: What is Barrel and Flow?
# Predicted Answer: Barrel and Flow is the nation's first Black beer festival, as well as the top beer festival in the country via USA Today's 10Best List.
# Actual Answer: First black beer festival in the nation; Popular beer festival in Pittsburgh
# Exact Match: False
# F1 Score: 0.3750
# Answer Recall: False
#
# Question: Who is Pittsburgh named after?
# Predicted Answer: William Pitt the Elder
# Actual Answer: William Pitt
# Exact Match: False
# F1 Score: 0.6667
# Answer Recall: True
#
# Question: What is the population of Pittsburgh?
# Predicted Answer: 302,971
# Actual Answer: 302,000
# Exact Match: False
# F1 Score: 0.0000
# Answer Recall: False
#
# Question: Where is Pittsburgh situated?
# Predicted Answer: Southwestern Pennsylvania, where the Ohio, Allegheny, and Monongahela Rivers meet.
# Actual Answer: Pennsylvania
# Exact Match: False
# F1 Score: 0.1818
# Answer Recall: True
#
# Question: When and who founded Pittsburgh?
# Predicted Answer: November 27, 1758, by General John Forbes in honor of British statesman William Pitt.
# Actual Answer: November 27, 1758 by John Forbes
# Exact Match: False
# F1 Score: 0.6000
# Answer Recall: True
#
# Question: What is the motto of Pittsburgh?
# Predicted Answer: Benigno Numine("With the benevolent deity")
# Actual Answer: Benigno Numine
# Exact Match: False
# F1 Score: 0.2857
# Answer Recall: False
#
# Question: What is the highest mountain in Pittsburgh?
# Predicted Answer: Mount Washington
# Actual Answer: 1,370 feet (420 meters)
# Exact Match: False
# F1 Score: 0.0000
# Answer Recall: False
#
# Question: Where is Farmer's Market held every year in Squirrel Hill?
# Predicted Answer: Squirrel Hill: Beacon/Bartlett parking lot (9 a.m. - 1 p.m.)
# Actual Answer: Beacon/Bartlett parking lot
# Exact Match: False
# F1 Score: 0.5000
# Answer Recall: True
#
# Question: Why festivals celebrates the beauty of Ikebana, traditional Japanese flower arrangement?
# Predicted Answer: Because it is exploring the captivating duality between the beauty of Ikebana and the eternal nature of well-crafted objects.
# Actual Answer: Gei: The Beauty of Ephemeral and Eternal
# Exact Match: False
# F1 Score: 0.3846
# Answer Recall: False
#
# Question: Which festival is known to be celebrated largest throughout the country in the city of Pittsburgh?
# Predicted Answer: Pittsburgh Folk Festival
# Actual Answer: St, Patricks Day
# Exact Match: False
# F1 Score: 0.0000
# Answer Recall: False
#
# Question: Which is the largest bicycle muesuem in the world?
# Predicted Answer: Bicycle Heaven
# Actual Answer: Bicycle Heaven
# Exact Match: True
# F1 Score: 1.0000
# Answer Recall: True
#
# Question: When did Penn brewery start?
# Predicted Answer: The year is not provided in the text.
# Actual Answer: 1986
# Exact Match: False
# F1 Score: 0.0000
# Answer Recall: False
#
# Question: What is Pittsburgh known as?
# Predicted Answer: The City of Pittsburgh offers everything a person might be looking for in a home, with its wonderful shopping areas, great restaurants, and beautiful views. It is also widely known as The Smoky City due to the pollution given off by steel factories, and The Gateway to the West.
# Actual Answer: Steel City
# Exact Match: False
# F1 Score: 0.0784
# Answer Recall: True
#
# Question: Which venue is hosting Donnie Iris & The Cruisers on October 26?
# Predicted Answer: Roxian Theatre
# Actual Answer: Roxian Theatre
# Exact Match: True
# F1 Score: 1.0000
# Answer Recall: True
#
# Question: What year was Carnegie Mellon University founded?
# Predicted Answer: 1900
# Actual Answer: 1900
# Exact Match: True
# F1 Score: 1.0000
# Answer Recall: True
#
# Question: Which Pittsburgh sports event recently celebrated the Immaculate Reception anniversary?
# Predicted Answer: City of Champions
# Actual Answer: Steelers Commemoration
# Exact Match: False
# F1 Score: 0.0000
# Answer Recall: False
#
# Question: Which music festival recently took place in Market Square?
# Predicted Answer: Soul Food Festival
# Actual Answer: Pittsburgh JazzLive
# Exact Match: False
# F1 Score: 0.0000
# Answer Recall: False
#
# Question: How many colleges does CMU have?
# Predicted Answer: Seven
# Actual Answer: Seven colleges.; 7
# Exact Match: False
# F1 Score: 0.6667
# Answer Recall: False
#
# Question: When was Schenley Skating Rink opened?
# Predicted Answer: 1975
# Actual Answer: 1975
# Exact Match: True
# F1 Score: 1.0000
# Answer Recall: True
#
# Question: What is CMU's annual event that showcases student projects?
# Predicted Answer: Like, Totally Transformative: CMU in the 1980s
# Actual Answer: Impact CMU
# Exact Match: False
# F1 Score: 0.2222
# Answer Recall: False
#
# Question: What is the name of CMU's sports teams?
# Predicted Answer: Tartans
# Actual Answer: The Tartans.; Tartans
# Exact Match: True
# F1 Score: 1.0000
# Answer Recall: True
#
# Question: What is the student newspaper at CMU?
# Predicted Answer: The Tartan.
# Actual Answer: The Tartan
# Exact Match: True
# F1 Score: 1.0000
# Answer Recall: True
#
# Question: What is the name of the venue hosting The Nutcracker?
# Predicted Answer: Phipps Conservatory and the Byham Theater
# Actual Answer: Benedum Center
# Exact Match: False
# F1 Score: 0.0000
# Answer Recall: False
#
# Question: Which event is happening at Benedum Center on January 7, 2025?
# Predicted Answer: No events listed.
# Actual Answer: Funny Girl
# Exact Match: False
# F1 Score: 0.0000
# Answer Recall: False
#
# Question: What is the title of the new musical event happening from October 29 to November 3, 2024?
# Predicted Answer: & Juliet
# Actual Answer: Bubble Boy: The Musical
# Exact Match: False
# F1 Score: 0.0000
# Answer Recall: False
#
# Question: Where is the Toronto Maple Leafs game against Pittsburgh Pirates taking place?
# Predicted Answer: PPG Paints Arena.
# Actual Answer: PPG Paints Arena
# Exact Match: True
# F1 Score: 1.0000
# Answer Recall: True
#
# Question: On which date and location will the Peter Pan event take place again?
# Predicted Answer: Tue, Apr 1 - Sun, Apr 6, 2025 Benedum Center
# Actual Answer: Tue, Apr 1 - Sun, Apr 6, 2025, Benedum Center
# Exact Match: True
# F1 Score: 0.8889
# Answer Recall: True
#
# Question: When are the Chicago White Sox games scheduled at PNC Park in July 2025?
# Predicted Answer: Event: Chicago White Sox
# Date: Jul 18, 2025
# Location:
# PNC Park 15212, Pittsburgh, Pennsylvania, US
# Link: https://pittsburgh.events/tickets/chicago-white-sox/
#
# Event: Chicago White Sox
# Date: Jul 19, 2025
# Location:
# PNC Park 15212, Pittsburgh, Pennsylvania, US
# Link: https://pittsburgh.events/tickets/chicago-white-sox/
#
# Event: Chicago White Sox
# Date: Jul 20, 2025
# Location:
# PNC Park 15212, Pittsburgh, Pennsylvania, US
# Link: https://pittsburgh.events/tickets/chicago-white-sox/
# Actual Answer: July 18, 2025, July 19, 2025, July 20, 2025
# Exact Match: False
# F1 Score: 0.1333
# Answer Recall: False
#
# Question: What is the date of Victor Wooten's concert?
# Predicted Answer: Oct. 9
# Actual Answer: October 9, 2024
# Exact Match: False
# F1 Score: 0.4000
# Answer Recall: False
#
# Question: What is the location of City Winery Pittsburgh?
# Predicted Answer: City Brew Tours Pittsburgh
# 120 Fifth Avenue Fifth Avenue Place Suite 2800Pittsburgh, PA 15222
# Actual Answer: Byham Theater; PPG Paints Arena
# Exact Match: False
# F1 Score: 0.0000
# Answer Recall: False
#
# Question: What is the title of the new musical event happening from October 29 to November 3, 2024?
# Predicted Answer: & Juliet
# Actual Answer: & Juliet
# Exact Match: True
# F1 Score: 1.0000
# Answer Recall: True
#
# Question: When does Eagle Fall Show Pittsburgh 2024 take place?
# Predicted Answer: Nov 23 - Nov 24, 2024
# Actual Answer: November 23, 2024 - November 24, 2024
# Exact Match: False
# F1 Score: 0.5455
# Answer Recall: False
#
# Question: What is the official dessert of Pennsylvania?
# Predicted Answer: The Banana Split
# Actual Answer: The Banana Split.
# Exact Match: True
# F1 Score: 1.0000
# Answer Recall: True
#
# Question: How long do experts believe it will take to transition away from natural gas as well as coal?
# Predicted Answer: No answer is provided.
# Actual Answer: Over 20-40 years.
# Exact Match: False
# F1 Score: 0.0000
# Answer Recall: False
#
# Question: What is the estimated damage from disasters in the U.S. during the most recent decade?
# Predicted Answer: $3B (2006 dollars).
# Actual Answer: $919 billion.
# Exact Match: False
# F1 Score: 0.0000
# Answer Recall: False
#
# Question: Which film festival is being celebrated from Nov 13 to Nov 20, 2024?
# Predicted Answer: The Three Rivers Film Festival
# Actual Answer: Three Rivers Film Festival
# Exact Match: False
# F1 Score: 0.8889
# Answer Recall: True
#
# Question: Where do drama students sign before graduating from CMU?
# Predicted Answer: Behind the stage of Kresge Theatre.
# Actual Answer: Kresge Theatre Stage
# Exact Match: False
# F1 Score: 0.6667
# Answer Recall: True
#
# Question: How much people are expected to be displaced due to climate change?
# Predicted Answer: Unfortunately the context does not provide enough information to answer this question.
# Actual Answer: 13 million
# Exact Match: False
# F1 Score: 0.0000
# Answer Recall: False
#
# Question: What was the wettest year in East Pittsburgh?
# Predicted Answer: Not available
# Actual Answer: 2018
# Exact Match: False
# F1 Score: 0.0000
# Answer Recall: False
#
# Question: When must an employer remit the Local Services Tax to the Treasurer?
# Predicted Answer: Thirty (30) days after the end of each quarter of a calendar year.
# Actual Answer: Thirty days after the end of each quarter of a calendar year
# Exact Match: False
# F1 Score: 0.8800
# Answer Recall: True
#
# Question: How much LST should be withheld from an employee who works part-time in Pittsburgh and Municipality "A"?
# Predicted Answer: $40 ($39 + $1) for 12 pay periods, then $1 per pay period.
# Actual Answer: $26
# Exact Match: False
# F1 Score: 0.0000
# Answer Recall: False
#
# Question: Does the employee owe the City of Pittsburgh $52 in LST if he only worked in the city for half the year?
# Predicted Answer: Yes. His employer knows that this employee is over the $12,000 low income exemption level. No exemption certificate has been filed. The $52 may be prorated for the rest of the year; however the employer should withhold $52 because that is what the employee owes.
# Actual Answer: Yes
# Exact Match: False
# F1 Score: 0.0435
# Answer Recall: True
#
# Question: Can an employee who filed their exemption certificate late receive a refund from their employer?
# Predicted Answer: Yes. The employee should request the refund from the employer. It is permissible and recommended that his employer refund the current year LST and make an adjustment for their next quarterly remittance to the City for the current year. If the employer does not refund the LST, the employee can apply for a refund from the City after the employer’s fourth quarter payment and summary form is filed at the end of the year.
# Actual Answer: Yes, the employee should request the refund from the employer.
# Exact Match: False
# F1 Score: 0.1860
# Answer Recall: True
#
# Question: What is the deadline for employers to file their tax return and pay the Local Services Tax?
# Predicted Answer: October 31
# Actual Answer: December 31
# Exact Match: False
# F1 Score: 0.5000
# Answer Recall: False
#
# Question: Can an employee's failure to withhold taxes from a previous employer relieve them from filing a return and paying the tax?
# Predicted Answer: No, it does.
# Actual Answer: No
# Exact Match: False
# F1 Score: 0.5000
# Answer Recall: True
#
# Question: When was the Mellon Institute of Industrial Research incorporated as an independent nonprofit?
# Predicted Answer: 1927
# Actual Answer: 1927
# Exact Match: True
# F1 Score: 1.0000
# Answer Recall: True
#
# Question: What architectural style did the campus begin to take shape in?
# Predicted Answer: Beaux-Arts
# Actual Answer: The Beaux-Arts architecture style
# Exact Match: False
# F1 Score: 0.4000
# Answer Recall: False
#
# Question: How much renewable energy has Carnegie Mellon been purchasing since 2011?
# Predicted Answer: 100%
# Actual Answer: 100%
# Exact Match: True
# F1 Score: 1.0000
# Answer Recall: True
#
# Question: When was the Gates Hillman Complex opened for occupancy?
# Predicted Answer: August 7, 2009.
# Actual Answer: August 7, 2009.
# Exact Match: True
# F1 Score: 1.0000
# Answer Recall: True
#
# Question: What is Carnegie Mellon University's acceptance rate?
# Predicted Answer: 11%
# Actual Answer: 11%
# Exact Match: True
# F1 Score: 1.0000
# Answer Recall: True

# %%
import pandas as pd

questions_df = pd.read_csv('test_questions.csv')

questions_df['Answer'] = ''

for index, row in questions_df.iterrows():
    query = row['Question']
    result = get_answer(query)
    questions_df.at[index, 'Answer'] = result

questions_df.to_csv('actual_test.csv', index=False)

print(questions_df)
# Out:
#                                               Question  \
# 0    What bank, which is the 5th largest in the US,...
# 1               How many bridges does Pittsburgh have?
# 2                    Who named the city of Pittsburgh?
# 3    At what park do the three rivers converge in P...
# 4         How many neighborhoods does Pittsburgh have?
# ..                                                 ...
# 569  What is the primary focus of the event at the ...
# 570  Where and when is the Pittsburgh Veg Fair held...
# 571  How can restaurants get involved with Pittsbur...
# 572  What are the benefits of sponsoring the Pittsb...
# 573  What is the recommended action for attendees w...
#
#                                                 Answer
# 0                                                  PNC
# 1                                                 2020
# 2                                 General John Forbes.
# 3                                    Point State Park.
# 4                                                   90
# ..                                                 ...
# 569                                       Dessert Wars
# 570                              May 4 | Rockwell Park
# 571  Participate by offering special dining deals f...
# 572  Increased exposure for your business, customer...
# 573  Enjoy and engage with activities, while also l...
#
# [574 rows x 2 columns]
